# %%
import csv

# %%
 with open('input_day1.txt', newline = '') as input:                                                                                          
        input_reader = csv.reader(input, delimiter='\t')
        for input in input_reader:
            print(input)
# Out:
# ['values']
# ['183']
# ['185']
# ['186']
# ['182']
# ['185']
# ['191']
# ['204']
# ['203']
# ['205']
# ['220']
# ['215']
# ['208']
# ['216']
# ['217']
# ['218']
# ['219']
# ['210']
# ['226']
# ['227']
# ['231']
# ['245']
# ['243']
# ['255']
# ['257']
# ['250']
# ['255']
# ['286']
# ['287']
# ['286']
# ['293']
# ['294']
# ['296']
# ['299']
# ['316']
# ['322']
# ['330']
# ['332']
# ['337']
# ['340']
# ['341']
# ['339']
# ['348']
# ['349']
# ['350']
# ['351']
# ['354']
# ['357']
# ['359']
# ['360']
# ['361']
# ['363']
# ['364']
# ['365']
# ['372']
# ['373']
# ['371']
# ['374']
# ['375']
# ['379']
# ['383']
# ['384']
# ['383']
# ['388']
# ['390']
# ['395']
# ['397']
# ['410']
# ['412']
# ['411']
# ['414']
# ['411']
# ['432']
# ['426']
# ['429']
# ['437']
# ['438']
# ['462']
# ['463']
# ['464']
# ['477']
# ['480']
# ['497']
# ['516']
# ['524']
# ['536']
# ['547']
# ['550']
# ['555']
# ['557']
# ['556']
# ['565']
# ['566']
# ['567']
# ['574']
# ['575']
# ['583']
# ['585']
# ['594']
# ...

# %%
type(input)
# Out:
# list

# %%
#input = [1,2,5,2,7,10,50,60,20]
count = 0
for i in range(len(input)):
    if input[i] < input[i+1] :
        count += 1
    else:
        count += 0
print('the input incremented', count, 'times')
# Out:
#   File "<ipython-input-8-6380f25b5c7e>", line 4
#     if input.[i,0] < input.[i+1,0] :
#              ^
# SyntaxError: invalid syntax
